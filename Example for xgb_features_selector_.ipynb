# %% [markdown]
# # **Example for xgb_features_selector**

# %% [markdown]
# **RELEASE**

# %%
REL = '_R005'

# %% [markdown]
# ## **Importing libraries and connecting disk, global ads**

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# Collecting own modules

# %%
import sys
sys.path.append('/gdrive/My Drive/Release')
import Modules.global_f as mgf
import Modules.xgb_features_selector as xgbfs
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import datetime
from google.colab import files

pd.set_option("display.max_columns", None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Data directories paths

# %%
DATA_PATH = '/gdrive/My Drive/Data/'
INDEXES_PATH = '/gdrive/My Drive/Data/Raw_data/Indexes/'
BRANCHES_PATH = '/gdrive/My Drive/Data//Raw_data/Branches/'

# %% [markdown]
# ##**Task implementation**

# %%
df_norm = pd.read_csv(DATA_PATH + 'Data_Cleaner_!!norm_cl!!_R004.csv')
ln = list(df_norm.columns)
df_norm.info(max_cols=125)

# %%
(x,y),(xv,yv) = xgbfs.get_feature_importance_data(df_norm, 'price', list_not_use_features=['Date'] + ln[2:43] )
res = xgbfs.xgb_get_feature_importance(x,y,xv,yv, verbose=1)
# Out:
# [17:41:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# {'merval': 0.0479, 'msci-world-index': 0.0397, 'asx-200': 0.1974, 'morgan-stanley-nyse': 0.2161, 'Dow Jones Telecommunications': 0.0168, 'NYSE Financials': 0.0334, 'NASDAQ Bank': 0.011, 'S&P 500 Industrials': 0.3549}

# %%
res.head()
# Out:
#      S&P 500 Industrials  morgan-stanley-nyse  asx-200  merval  \
# res                 0.35                 0.22     0.20    0.05
#
#      msci-world-index  NYSE Financials  Dow Jones Telecommunications  \
# res              0.04             0.03                          0.02
#
#      NASDAQ Bank
# res         0.01
