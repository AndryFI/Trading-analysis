# %% [markdown]
# # **Test LSTM and Conv with   xgb_features_selector**

# %% [markdown]
# **RELEASE**

# %%
REL = '_R005'

# %% [markdown]
# ## **Importing libraries and connecting disk, global ads**

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# Collecting own modules

# %%
import sys
sys.path.append('/gdrive/My Drive/Release/')
import Modules.global_f as mgf
import Modules.xgb_features_selector as xgbfs
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Функции

# %%
# Нормирование
def norm_df(df,  shift=1, list_rename=[], cols=[], no_cols=[]):
  df_ = df.copy()
  if cols == []:
    cols = df_.columns
  else: shift = 0
  for k in cols[shift:]:
    if k not in no_cols:
      min_ = df_[k].min()
      max_ = df_[k].max()
      if k in list_rename:
          df_['n_' + k] = df_[k].apply(lambda x: (x-min_)/(max_-min_))
      else:
          df_[k] = df_[k].apply(lambda x: (x-min_)/(max_-min_))
  return df_

# %%
#  Z преобразование
def z_df(df,  shift=1, list_rename=[], cols=[], no_cols=[]):
  df_ = df.copy()
  if cols == []:
    cols = df_.columns
  else: shift = 0
  for k in cols[shift:]:
    if k not in no_cols:
      _mean = df_[k].mean()
      _std = df_[k].std()
      if k in list_rename:
          df_['z_' + k] = df_[k].apply(lambda x: (x -_mean)/_std)
      else:
          df_[k] = df_[k].apply(lambda x: (x -_mean)/_std)
  return df_

# %%
def shift_from_end(xs, n):
    e = np.empty_like(xs)
    if n >= 0:
        e[:-n] = xs[n:]
        e[-n:] = xs[-1:]
    return e

# %%
def supplement(xs, n, set_adds = np.nan): # Дополняет  данные значениями set_adds с начала или с конца (+ n или - n )  
    xs = xs.flatten()
    e = np.empty(abs(n))
    e[:abs(n)] = set_adds
    if n > 0:
      e = np.append(e, xs, axis = 0)
    if n < 0:
      e = np.append(xs, e, axis = 0)
    return e

# %%
# Функция добавляет столбцы с ifft  в   датасет в соответствии с фильтрами list_comp_fft, возвращает датасет
def ifft_add_columns(df_, key_, list_comp_fft, n_adds =1):
  _df_ = df_.copy()
  _df_.reset_index()
  arr_big = np.array(_df_[key_]).flatten()
  arr_big = supplement(arr_big,n_adds,arr_big[0])
  arr_big = supplement(arr_big,-n_adds,arr_big[0])
  #print(arr_big.shape)
  #close_fft = np.fft.fft(np.asarray(_df_[key_].tolist()))
  close_fft = np.fft.fft(arr_big)
  fft_df = pd.DataFrame({'fft':close_fft})
  fft_df['absolute'] = fft_df['fft'].apply(lambda x: np.abs(x))
  fft_df['angle'] = fft_df['fft'].apply(lambda x: np.angle(x))
  fft_list = np.asarray(fft_df['fft'].tolist())
  #print(fft_list.shape)
  for num_ in list_comp_fft:  # числа убирают из центра часточного распределения num_ компонент fft
    fft_list_filtered= np.copy(fft_list)
    fft_list_filtered[num_:-num_] = 0
    ifft_  = np.fft.ifft(fft_list_filtered)
    ifft_df = pd.DataFrame({'ifft':ifft_})
    ifft_df[key_ + '_'+ str(num_)+ '_ifft'] = ifft_df['ifft'].apply(lambda x: np.abs(x))
    ifft_df = ifft_df.drop(columns=['ifft'])
    ifft_df = ifft_df[n_adds:-n_adds].reset_index(drop = True)
    #print(ifft_df.shape)
    _df_ = pd.concat([_df_, ifft_df], axis=1)
    print(_df_.shape)
  return _df_

# %% [markdown]
# # Реализация

# %%
DATA_PATH = '/gdrive/My Drive/Data/' 
W_PATH = '/gdrive/My Drive/Drafts/TEST_LSTM_Conv_BITC/'

KEY = 'Bitcoin Historical Data_Price'#'FTSE 100 Historical Data_Price'#'NYSE Composite Historical Data_Price' #GS_Price'#'USD_RUB Historical Data_Price'#
GS_KEY = 'GS_Price'

# %%
import pandas as pd
#data = pd.read_csv(DATA_PATH + 'data_cleaner_!!clear!!_R001.csv', engine='python')  #, usecols=[1,2,3,4,5,6,7,8,9]
pd.set_option('display.max_columns', None)
df = pd.read_csv(DATA_PATH + 'df_all_scores.csv', parse_dates=[0])
df
# Out:
#            Date  GS_Price  GS_Open  GS_High  GS_Low       GS_Vol.  \
# 0    2011-04-19    151.86   156.09   156.10  149.55  1.347000e+09
# 1    2011-04-20    152.70   153.17   154.15  151.50  7.190000e+08
# 2    2011-04-21    153.51   153.09   154.33  152.70  3.980000e+08
# 3    2011-04-25    152.19   152.58   152.59  151.18  3.710000e+08
# 4    2011-04-26    153.27   151.89   153.95  151.78  4.370000e+08
# ...         ...       ...      ...      ...     ...           ...
# 2511 2021-04-13    327.68   329.36   329.75  324.25  3.580000e+08
# 2512 2021-04-14    335.35   328.69   344.43  326.73  9.880000e+08
# 2513 2021-04-15    338.55   339.67   341.35  334.64  4.350000e+08
# 2514 2021-04-16    342.31   340.29   343.74  338.62  4.230000e+08
# 2515 2021-04-19    343.09   340.71   344.38  336.71  3.230000e+08
#
#       GS_Change %  GS_diffCO  GS_diffHL  FTSE 100 Historical Data_Price  \
# 0           -1.25      -4.23       6.55                         5896.87
# 1            0.55      -0.47       2.65                         6022.26
# 2            0.53       0.42       1.63                         6018.30
# 3           -0.86      -0.39       1.41                         6043.83
# 4            0.71       1.38       2.17                         6069.36
# ...           ...        ...        ...                             ...
# 2511        -1.25      -1.68       5.50                         6890.49
# 2512         2.34       6.66      17.70                         6939.58
# 2513         0.95      -1.12       6.71                         6983.50
# 2514         1.11       2.02       5.12                         7019.53
# 2515         0.23       2.38       7.67                         7000.08
#
#       FTSE 100 Historical Data_Open  FTSE 100 Historical Data_High  \
# 0                           5903.00                        5921.30
# 1                           5953.80                        6034.80
# 2                           6053.90                        6053.90
# 3                           6030.00                        6063.45
# 4                           6006.10                        6073.00
# ...                             ...                            ...
# 2511                        6889.12                        6895.13
# 2512                        6890.49                        6942.33
# 2513                        6939.58                        6994.90
# 2514                        6983.50                        7037.65
# 2515                        7019.53                        7040.26
#
#       FTSE 100 Historical Data_Low  FTSE 100 Historical Data_Vol.  \
# 0                          5889.80                   0.000000e+00
# 1                          5953.80                   0.000000e+00
# 2                          6007.80                   0.000000e+00
# 3                          6006.65                   0.000000e+00
# 4                          6005.50                   0.000000e+00
# ...                            ...                            ...
# 2511                       6859.72                   5.724100e+10
# 2512                       6880.67                   5.967700e+10
# 2513                       6939.26                   6.512800e+10
# 2514                       6983.50                   7.425100e+10
# 2515                       6979.23                   5.297100e+10
#
#       FTSE 100 Historical Data_Change %  FTSE 100 Historical Data_diffCO  \
#       S&P 500 Historical Data_Price  S&P 500 Historical Data_Open  \
# 0                           1312.62                       1305.99
# 1                           1330.36                       1319.12
# 2                           1337.38                       1333.23
# 3                           1335.25                       1337.14
# 4                           1347.24                       1336.75
# ...                             ...                           ...
# 2511                        4141.59                       4130.10
# 2512                        4124.66                       4141.58
# 2513                        4170.42                       4139.76
# 2514                        4185.47                       4174.14
# 2515                        4163.26                       4179.80
#
#       S&P 500 Historical Data_High  S&P 500 Historical Data_Low  \
# 0                          1312.70                      1303.97
# 1                          1332.66                      1319.12
# 2                          1337.49                      1332.83
# 3                          1337.55                      1331.47
# 4                          1349.55                      1336.75
# ...                            ...                          ...
# 2511                       4148.00                      4124.43
# 2512                       4151.69                      4120.87
# 2513                       4173.49                      4139.76
# 2514                       4191.31                      4170.75
# 2515                       4180.81                      4150.47
#
#       S&P 500 Historical Data_Change %  S&P 500 Historical Data_diffCO  \
# 0                                 0.57                            6.63
# 1                                 1.35                           11.24
# 2                                 0.53                            4.15
# 3                                -0.16                           -1.89
# 4                                 0.90                           10.49
# ...                                ...                             ...
# 2511                              0.33                           11.49
# 2512                             -0.41                          -16.92
# 2513                              1.11                           30.66
# 2514                              0.36                           11.33
# 2515                             -0.53                          -16.54
#
#       S&P 500 Historical Data_diffHL  DAX Historical Data_Price  \
# 0                               8.73                    7039.31
# 1                              13.54                    7249.19
# 2                               4.66                    7295.49
# 3                               6.08                    7326.00
# 4                              12.80                    7356.51
# ...                              ...                        ...
# 2511                           23.57                   15234.36
# 2512                           30.82                   15209.15
# 2513                           33.73                   15255.33
# 2514                           20.56                   15459.75
# 2515                           30.34                   15368.39
#
#       DAX Historical Data_Open  DAX Historical Data_High  \
# 0                     7050.850                   7078.79
# 1                     7137.100                   7261.26
# 2                     7294.580                   7316.53
# 3                     7291.675                   7338.25
# 4                     7288.770                   7359.97
# ...                        ...                       ...
# 2511                 15244.620                  15281.65
# 2512                 15253.590                  15255.92
# 2513                 15238.630                  15271.69
# 2514                 15277.850                  15473.83
# 2515                 15496.870                  15501.84
#
#       DAX Historical Data_Low  DAX Historical Data_Vol.  \
# 0                     7027.04              1.306500e+10
# 1                     7136.74              1.426100e+10
# 2                     7280.10              1.155500e+10
# 3                     7279.31              9.956500e+09
# 4                     7278.52              8.358000e+09
# ...                       ...                       ...
# 2511                 15184.95              6.244000e+09
# 2512                 15191.51              6.667000e+09
# 2513                 15227.63              6.183000e+09
# 2514                 15274.22              8.276000e+09
# 2515                 15368.14              6.184000e+09
#
#       DAX Historical Data_Change %  DAX Historical Data_diffCO  \
# 0                             0.18                     -11.540
# 1                             2.98                     112.090
# 2                             0.64                       0.910
# 3                             0.74                      34.325
# 4                             0.84                      67.740
# ...                            ...                         ...
# 2511                          0.13                     -10.260
# 2512                         -0.17                     -44.440
# 2513                          0.30                      16.700
# 2514                          1.34                     181.900
# 2515                         -0.59                    -128.480
#
#       DAX Historical Data_diffHL  CAC 40 Historical Data_Price  \
# 0                          51.75                      3908.580
# 1                         124.52                      4004.620
# 2                          36.43                      4021.880
# 3                          58.94                      4033.585
# 4                          81.45                      4045.290
# ...                          ...                           ...
# 2511                       96.70                      6184.100
# 2512                       64.41                      6208.580
# 2513                       44.06                      6234.140
# 2514                      199.61                      6287.070
# 2515                      133.70                      6296.690
#
#       CAC 40 Historical Data_Open  CAC 40 Historical Data_High  \
# 0                         3899.68                      3929.17
# 1                         3947.46                      4008.74
# 2                         4021.91                      4034.50
# 3                         4018.10                      4041.25
# 4                         4014.29                      4048.00
# ...                           ...                          ...
# 2511                      6171.88                      6193.24
# 2512                      6214.49                      6217.74
# 2513                      6219.04                      6244.23
# 2514                      6229.65                      6299.56
# 2515                      6294.74                      6319.08
#
#       CAC 40 Historical Data_Low  CAC 40 Historical Data_Vol.  \
# 0                        3895.38                 1.222000e+10
# 1                        3947.46                 1.451800e+10
# 2                        4011.38                 1.179800e+10
# 3                        4010.60                 1.177950e+10
# 4                        4009.82                 1.176100e+10
# ...                          ...                          ...
# 2511                     6156.49                 7.472000e+09
# 2512                     6194.55                 6.106000e+09
# 2513                     6209.59                 6.620000e+09
# 2514                     6229.30                 8.638000e+09
# 2515                     6293.17                 5.853000e+09
#
#       CAC 40 Historical Data_Change %  CAC 40 Historical Data_diffCO  \
# 0                               0.700                          8.900
# 1                               2.460                         57.160
# 2                               0.430                         -0.030
# 3                               0.505                         15.485
# 4                               0.580                         31.000
# ...                               ...                            ...
# 2511                            0.360                         12.220
# 2512                            0.400                         -5.910
# 2513                            0.410                         15.100
# 2514                            0.850                         57.420
# 2515                            0.150                          1.950
#
#       CAC 40 Historical Data_diffHL  Nikkei 225 Historical Data_Price  \
# 0                             33.79                           9441.03
# 1                             61.28                           9606.82
# 2                             23.12                           9685.77
# 3                             30.65                           9671.96
# 4                             38.18                           9558.69
# ...                             ...                               ...
# 2511                          36.75                          29751.61
# 2512                          23.19                          29620.99
# 2513                          34.64                          29642.69
# 2514                          70.26                          29683.37
# 2515                          25.91                          29685.37
#
#       Nikkei 225 Historical Data_Open  Nikkei 225 Historical Data_High  \
# 0                             9441.00                          9481.50
# 1                             9546.00                          9631.50
# 2                             9691.00                          9726.50
# 3                             9701.00                          9746.50
# 4                             9621.00                          9621.50
# ...                               ...                              ...
# 2511                         29605.69                         29897.11
# 2512                         29718.06                         29722.40
# 2513                         29573.90                         29787.66
# 2514                         29789.08                         29789.08
# 2515                         29688.32                         29808.01
#
#       Nikkei 225 Historical Data_Low  Nikkei 225 Historical Data_Vol.  \
# 0                            9391.50                     0.000000e+00
# 1                            9516.50                     0.000000e+00
# 2                            9646.50                     0.000000e+00
# 3                            9656.50                     0.000000e+00
# 4                            9536.50                     0.000000e+00
# ...                              ...                              ...
# 2511                        29573.79                     5.488800e+10
# 2512                        29567.18                     5.716900e+10
# 2513                        29558.55                     5.062100e+10
# 2514                        29621.83                     4.908300e+10
# 2515                        29530.84                     4.469900e+10
#
#       Nikkei 225 Historical Data_Change %  Nikkei 225 Historical Data_diffCO  \
# 0                                   -1.21                               0.03
# 1                                    1.76                              60.82
# 2                                    0.82                              -5.23
# 3                                   -0.11                             -29.04
# 4                                   -1.17                             -62.31
# ...                                   ...                                ...
# 2511                                 0.72                             145.92
# 2512                                -0.44                             -97.07
# 2513                                 0.07                              68.79
# 2514                                 0.14                            -105.71
# 2515                                 0.01                              -2.95
#
#       Nikkei 225 Historical Data_diffHL  \
# 0                                 90.00
# 1                                115.00
# 2                                 80.00
# 3                                 90.00
# 4                                 85.00
# ...                                 ...
# 2511                             323.32
# 2512                             155.22
# 2513                             229.11
# 2514                             167.25
# 2515                             277.17
#
#       Shanghai Composite Historical Data_Price  \
# 0                                      2999.04
# 1                                      3007.04
# 2                                      3026.67
# 3                                      2964.95
# 4                                      2938.98
# ...                                        ...
# 2511                                   3396.47
# 2512                                   3416.72
# 2513                                   3398.99
# 2514                                   3426.62
# 2515                                   3477.55
#
#       Shanghai Composite Historical Data_Open  \
# 0                                     3038.81
# 1                                     3005.97
# 2                                     3021.77
# 3                                     3003.03
# 4                                     2956.95
# ...                                       ...
# 2511                                  3411.29
# 2512                                  3397.02
# 2513                                  3409.61
# 2514                                  3407.19
# 2515                                  3427.55
#
#       Shanghai Composite Historical Data_High  \
# 0                                     3038.81
# 1                                     3019.12
# 2                                     3035.47
# 3                                     3003.61
# 4                                     2970.28
# ...                                       ...
# 2511                                  3425.39
# 2512                                  3420.03
# 2513                                  3409.61
# 2514                                  3432.63
# 2515                                  3479.01
#
#       Shanghai Composite Historical Data_Low  \
# 0                                    2996.22
# 1                                    2992.67
# 2                                    3012.54
# 3                                    2964.64
# 4                                    2931.50
# ...                                      ...
# 2511                                 3387.90
# 2512                                 3392.98
# 2513                                 3373.09
# 2514                                 3394.13
# 2515                                 3414.36
#
#       Shanghai Composite Historical Data_Vol.  \
# 0                                1.419000e+12
# 1                                1.197000e+12
# 2                                1.215000e+12
# 3                                1.173000e+12
# 4                                9.520000e+11
# ...                                       ...
# 2511                             2.706000e+12
# 2512                             2.332000e+12
# 2513                             2.340000e+12
# 2514                             2.586000e+12
# 2515                             3.027000e+12
#
#       Shanghai Composite Historical Data_Change %  \
# 0                                           -1.91
# 1                                            0.27
# 2                                            0.65
# 3                                           -1.51
# 4                                           -0.88
# ...                                           ...
# 2511                                        -0.48
# 2512                                         0.60
# 2513                                        -0.52
# 2514                                         0.81
# 2515                                         1.49
#
#       Shanghai Composite Historical Data_diffCO  \
# 0                                        -39.77
# 1                                          1.07
# 2                                          4.90
# 3                                        -38.08
# 4                                        -17.97
# ...                                         ...
# 2511                                     -14.82
# 2512                                      19.70
# 2513                                     -10.62
# 2514                                      19.43
# 2515                                      50.00
#
#       Shanghai Composite Historical Data_diffHL  \
# 0                                         42.59
# 1                                         26.45
# 2                                         22.93
# 3                                         38.97
# 4                                         38.78
# ...                                         ...
# 2511                                      37.49
# 2512                                      27.05
# 2513                                      36.52
# 2514                                      38.50
# 2515                                      64.65
#
#       Hang Seng Historical Data_Price  Hang Seng Historical Data_Open  \
# 0                           23520.620                        23591.00
# 1                           23896.100                        23677.00
# 2                           24138.310                        24056.00
# 3                           24072.845                        23991.50
# 4                           24007.380                        23927.00
# ...                               ...                             ...
# 2511                        28497.250                        28557.84
# 2512                        28900.830                        28796.55
# 2513                        28793.140                        28872.82
# 2514                        28969.710                        28827.17
# 2515                        29106.150                        28960.13
#
#       Hang Seng Historical Data_High  Hang Seng Historical Data_Low  \
# 0                           23600.00                       23419.00
# 1                           23896.10                       23632.00
# 2                           24185.00                       24017.00
# 3                           24129.00                       23907.50
# 4                           24073.00                       23798.00
# ...                              ...                            ...
# 2511                        28877.15                       28452.12
# 2512                        28979.35                       28685.06
# 2513                        28884.57                       28530.99
# 2514                        29079.18                       28711.11
# 2515                        29319.76                       28806.76
#
#       Hang Seng Historical Data_Vol.  Hang Seng Historical Data_Change %  \
# 0                       0.000000e+00                              -1.300
# 1                       0.000000e+00                               1.600
# 2                       0.000000e+00                               1.010
# 3                       0.000000e+00                               0.235
# 4                       0.000000e+00                              -0.540
# ...                              ...                                 ...
# 2511                    2.060000e+11                               0.150
# 2512                    1.940000e+11                               1.420
# 2513                    1.900000e+11                              -0.370
# 2514                    2.190000e+11                               0.610
# 2515                    2.020000e+11                               0.470
#
#       Hang Seng Historical Data_diffCO  Hang Seng Historical Data_diffHL  \
# 0                              -70.380                            181.00
# 1                              219.100                            264.10
# 2                               82.310                            168.00
# 3                               81.345                            221.50
# 4                               80.380                            275.00
# ...                                ...                               ...
# 2511                           -60.590                            425.03
# 2512                           104.280                            294.29
# 2513                           -79.680                            353.58
# 2514                           142.540                            368.07
# 2515                           146.020                            513.00
#
#       KOSPI Historical Data_Price  KOSPI Historical Data_Open  \
# 0                         2122.68                     2117.94
# 1                         2169.91                     2146.38
# 2                         2198.54                     2190.64
# 3                         2216.00                     2205.20
# 4                         2206.30                     2219.47
# ...                           ...                         ...
# 2511                      3169.08                     3138.21
# 2512                      3182.38                     3169.95
# 2513                      3194.33                     3180.73
# 2514                      3198.62                     3194.08
# 2515                      3198.84                     3201.11
#
#       KOSPI Historical Data_High  KOSPI Historical Data_Low  \
# 0                        2136.95                    2111.60
# 1                        2169.94                    2138.80
# 2                        2211.36                    2183.52
# 3                        2218.07                    2199.27
# 4                        2222.56                    2196.76
# ...                          ...                        ...
# 2511                     3173.26                    3136.99
# 2512                     3188.32                    3162.12
# 2513                     3204.48                    3178.99
# 2514                     3206.76                    3185.67
# 2515                     3214.45                    3193.40
#
#       KOSPI Historical Data_Vol.  KOSPI Historical Data_Change %  \
# 0                   3.750200e+10                           -0.70
# 1                   3.743200e+10                            2.23
# 2                   4.159800e+10                            1.32
# 3                   3.540200e+10                            0.83
# 4                   4.393400e+10                           -0.44
# ...                          ...                             ...
# 2511                1.740000e+11                            1.07
# 2512                1.780000e+11                            0.42
# 2513                1.310000e+11                            0.38
# 2514                9.852800e+10                            0.13
# 2515                1.050000e+08                            0.01
#
#       KOSPI Historical Data_diffCO  KOSPI Historical Data_diffHL  \
# 0                             4.74                         25.35
# 1                            23.53                         31.14
# 2                             7.90                         27.84
# 3                        66552.06                  1.390000e+08
# 4                        66722.43                  1.730000e+08
# ...                           ...                           ...
# 2511                    118041.14                  8.980000e+08
# 2512                    119297.53                  1.008000e+09
# 2513                    120083.97                  7.950000e+08
# 2514                    120198.90                  7.950000e+08
# 2515                    120682.17                  1.003000e+09
#
#       Bovespa Historical Data_Change %  Bovespa Historical Data_diffCO  \
# 0                                1.140                         741.390
# 1                                1.360                         893.080
# 2                                0.615                         403.715
# 3                               -0.130                         -85.650
# 4                                0.260                         172.370
# ...                                ...                             ...
# 2511                             0.410                         487.780
# 2512                             0.840                         997.150
# 2513                             0.340                         410.410
# 2514                             0.340                         413.260
# 2515                            -0.150                        -182.270
#
#       Bovespa Historical Data_diffHL  S&P Merval Historical Data_Price  \
# 0                            840.240                          3332.270
# 1                            911.820                          3413.940
# 2                            742.045                          3407.545
# 3                            572.270                          3401.150
# 4                            690.730                          3374.200
# ...                              ...                               ...
# 2511                        1488.020                         47679.060
# 2512                        1573.920                         47299.010
# 2513                        1324.750                         47093.250
# 2514                        1134.460                         47664.350
# 2515                        1292.040                         48026.290
#
#       S&P Merval Historical Data_Open  S&P Merval Historical Data_High  \
# 0                             3305.03                         3337.620
# 1                             3338.28                         3413.940
# 2                             3377.12                         3415.295
# 3                             3415.96                         3416.650
# 4                             3401.82                         3409.450
# ...                               ...                              ...
# 2511                         48109.61                        48173.640
# 2512                         47679.06                        48360.710
# 2513                         47299.01                        47655.920
# 2514                         47093.25                        47734.170
# 2515                         47664.35                        48298.910
#
#       S&P Merval Historical Data_Low  S&P Merval Historical Data_Change %  \
# 0                            3305.03                                 0.95
# 1                            3336.05                                 2.45
# 2                            3364.84                                 1.04
# 3                            3393.63                                -0.37
# 4                            3368.74                                -0.79
# ...                              ...                                  ...
# 2511                        47604.20                                -0.89
# 2512                        47214.71                                -0.80
# 2513                        47040.78                                -0.44
# 2514                        46813.22                                 1.21
# 2515                        47628.22                                 0.76
#
#       S&P Merval Historical Data_diffCO  S&P Merval Historical Data_diffHL  \
# 0                                27.240                             32.590
# 1                                75.660                             77.890
# 2                                30.425                             50.455
# 3                               -14.810                             23.020
# 4                               -27.620                             40.710
# ...                                 ...                                ...
# 2511                           -430.550                            569.440
# 2512                           -380.050                           1146.000
# 2513                           -205.760                            615.140
# 2514                            571.100                            920.950
# 2515                            361.940                            670.690
#
#       CBOE Volatility Index Historical Data_Price  \
# 0                                           15.83
# 1                                           15.07
# 2                                           14.69
# 3                                           15.77
# 4                                           15.62
# ...                                           ...
# 2511                                        16.65
# 2512                                        16.99
# 2513                                        16.57
# 2514                                        16.25
# 2515                                        17.29
#
#       CBOE Volatility Index Historical Data_Open  \
# 0                                          16.62
# 1                                          14.31
# 2                                          14.71
# 3                                          15.64
# 4                                          15.36
# ...                                          ...
# 2511                                       16.99
# 2512                                       16.71
# 2513                                       16.78
# 2514                                       16.65
# 2515                                       17.05
#
#       CBOE Volatility Index Historical Data_High  \
# 0                                          16.72
# 1                                          15.39
# 2                                          15.23
# 3                                          16.06
# 4                                          15.66
# ...                                          ...
# 2511                                       17.86
# 2512                                       17.69
# 2513                                       16.92
# 2514                                       16.88
# 2515                                       18.61
#
#       CBOE Volatility Index Historical Data_Low  \
# 0                                         15.69
# 1                                         14.30
# 2                                         14.40
# 3                                         15.50
# 4                                         15.07
# ...                                         ...
# 2511                                      16.43
# ...
#
#       S&P 500 Materials Historical Data_Low  \
# 0                                    241.92
# 1                                    246.18
# 2                                    249.19
# 3                                    249.06
# 4                                    250.21
# ...                                     ...
# 2511                                 501.09
# 2512                                 503.56
# 2513                                 507.46
# 2514                                 517.06
# 2515                                 513.90
#
#       S&P 500 Materials Historical Data_Change %  \
# 0                                           1.76
# 1                                           1.22
# 2                                           1.08
# 3                                          -0.67
# 4                                           1.04
# ...                                          ...
# 2511                                       -0.19
# 2512                                        0.65
# 2513                                        1.26
# 2514                                        1.18
# 2515                                       -0.44
#
#       S&P 500 Materials Historical Data_diffCO  \
# 0                                         4.26
# 1                                         3.01
# 2                                         2.70
# 3                                        -1.68
# 4                                         2.61
# ...                                        ...
# 2511                                     -0.41
# 2512                                      2.90
# 2513                                      2.85
# 2514                                      0.10
# 2515                                     -2.92
#
#       S&P 500 Materials Historical Data_diffHL  \
# 0                                         4.46
# 1                                         4.80
# 2                                         2.78
# 3                                         3.15
# 4                                         3.54
# ...                                        ...
# 2511                                      3.72
# 2512                                      5.27
# 2513                                      6.38
# 2514                                      3.45
# 2515                                      6.12
#
#       S&P 500 Real Estate Historical Data_Price  \
# 0                                        131.55
# 1                                        133.11
# 2                                        133.89
# 3                                        134.74
# 4                                        136.08
# ...                                         ...
# 2511                                     255.16
# 2512                                     253.39
# 2513                                     258.34
# 2514                                     258.78
# 2515                                     259.54
#
#       S&P 500 Real Estate Historical Data_Open  \
# 0                                       130.44
# 1                                       131.64
# 2                                       133.12
# 3                                       133.89
# 4                                       134.74
# ...                                        ...
# 2511                                    253.43
# 2512                                    254.88
# 2513                                    254.54
# 2514                                    259.40
# 2515                                    258.95
#
#       S&P 500 Real Estate Historical Data_High  \
# 0                                       131.57
# 1                                       133.18
# 2                                       133.90
# 3                                       135.21
# 4                                       136.32
# ...                                        ...
# 2511                                    255.36
# 2512                                    256.31
# 2513                                    258.38
# 2514                                    259.58
# 2515                                    259.58
#
#       S&P 500 Real Estate Historical Data_Low  \
# 0                                      130.44
# 1                                      131.64
# 2                                      132.51
# 3                                      133.40
# 4                                      134.55
# ...                                       ...
# 2511                                   253.13
# 2512                                   253.25
# 2513                                   254.54
# 2514                                   258.07
# 2515                                   257.26
#
#       S&P 500 Real Estate Historical Data_Change %  \
# 0                                             0.87
# 1                                             1.19
# 2                                             0.59
# 3                                             0.63
# 4                                             0.99
# ...                                            ...
# 2511                                          0.63
# 2512                                         -0.69
# 2513                                          1.95
# 2514                                          0.17
# 2515                                          0.29
#
#       S&P 500 Real Estate Historical Data_diffCO  \
# 0                                           1.11
# 1                                           1.47
# 2                                           0.77
# 3                                           0.85
# 4                                           1.34
# ...                                          ...
# 2511                                        1.73
# 2512                                       -1.49
# 2513                                        3.80
# 2514                                       -0.62
# 2515                                        0.59
#
#       S&P 500 Real Estate Historical Data_diffHL  \
# 0                                           1.13
# 1                                           1.54
# 2                                           1.39
# 3                                           1.81
# 4                                           1.77
# ...                                          ...
# 2511                                        2.23
# 2512                                        3.06
# 2513                                        3.84
# 2514                                        1.51
# 2515                                        2.32
#
#       S&P 500 Telecom Services Historical Data_Price  \
# 0                                             130.42
# 1                                             130.99
# 2                                             131.38
# 3                                             131.07
# 4                                             132.98
# ...                                              ...
# 2511                                          250.65
# 2512                                          248.49
# 2513                                          251.65
# 2514                                          251.93
# 2515                                          251.24
#
#       S&P 500 Telecom Services Historical Data_Open  \
# 0                                            130.50
# 1                                            130.42
# 2                                            130.99
# 3                                            131.38
# 4                                            131.07
# ...                                             ...
# 2511                                         250.43
# 2512                                         250.65
# 2513                                         248.49
# 2514                                         251.65
# 2515                                         251.93
#
#       S&P 500 Telecom Services Historical Data_High  \
# 0                                            130.99
# 1                                            131.71
# 2                                            131.59
# 3                                            131.48
# 4                                            133.18
# ...                                             ...
# 2511                                         251.94
# 2512                                         250.68
# 2513                                         252.54
# 2514                                         252.66
# 2515                                         253.07
#
#       S&P 500 Telecom Services Historical Data_Low  \
# 0                                           130.06
# 1                                           130.37
# 2                                           130.44
# 3                                           130.60
# 4                                           131.07
# ...                                            ...
# 2511                                        250.40
# 2512                                        248.04
# 2513                                        248.49
# 2514                                        251.01
# 2515                                        249.81
#
#       S&P 500 Telecom Services Historical Data_Change %  \
# 0                                                 -0.06
# 1                                                  0.44
# 2                                                  0.30
# 3                                                 -0.24
# 4                                                  1.46
# ...                                                 ...
# 2511                                               0.09
# 2512                                              -0.86
# 2513                                               1.27
# 2514                                               0.11
# 2515                                              -0.27
#
#       S&P 500 Telecom Services Historical Data_diffCO  \
# 0                                               -0.08
# 1                                                0.57
# 2                                                0.39
# 3                                               -0.31
# 4                                                1.91
# ...                                               ...
# 2511                                             0.22
# 2512                                            -2.16
# 2513                                             3.16
# 2514                                             0.28
# 2515                                            -0.69
#
#       S&P 500 Telecom Services Historical Data_diffHL  \
# 0                                                0.93
# 1                                                1.34
# 2                                                1.15
# 3                                                0.88
# 4                                                2.11
# ...                                               ...
# 2511                                             1.54
# 2512                                             2.64
# 2513                                             4.05
# 2514                                             1.65
# 2515                                             3.26
#
#       NASDAQ Computer Historical Data_Price  \
# 0                                   1394.54
# 1                                   1429.31
# 2                                   1439.40
# 3                                   1446.65
# 4                                   1458.42
# ...                                     ...
# 2511                                9844.30
# 2512                                9714.52
# 2513                                9887.55
# 2514                                9868.94
# 2515                                9775.43
#
#       NASDAQ Computer Historical Data_Open  \
# 0                                  1388.30
# 1                                  1422.75
# 2                                  1443.13
# 3                                  1439.27
# 4                                  1449.86
# ...                                    ...
# 2511                               9782.72
# 2512                               9840.08
# 2513                               9817.06
# 2514                               9891.54
# 2515                               9821.33
#
#       NASDAQ Computer Historical Data_High  \
# 0                                  1394.54
# 1                                  1431.13
# 2                                  1443.14
# 3                                  1446.89
# 4                                  1465.20
# ...                                    ...
# 2511                               9857.18
# 2512                               9845.06
# 2513                               9896.61
# 2514                               9893.27
# 2515                               9885.93
#
#       NASDAQ Computer Historical Data_Low  \
# 0                                 1383.42
# 1                                 1419.41
# 2                                 1432.54
# 3                                 1439.18
# 4                                 1446.99
# ...                                   ...
# 2511                              9775.78
# 2512                              9701.40
# 2513                              9812.27
# 2514                              9817.16
# 2515                              9715.48
#
#       NASDAQ Computer Historical Data_Change %  \
# 0                                         0.60
# 1                                         2.49
# 2                                         0.71
# 3                                         0.50
# 4                                         0.81
# ...                                        ...
# 2511                                      1.08
# 2512                                     -1.32
# 2513                                      1.78
# 2514                                     -0.19
# 2515                                     -0.95
#
#       NASDAQ Computer Historical Data_diffCO  \
# 0                                       6.24
# 1                                       6.56
# 2                                      -3.73
# 3                                       7.38
# 4                                       8.56
# ...                                      ...
# 2511                                   61.58
# 2512                                 -125.56
# 2513                                   70.49
# 2514                                  -22.60
# 2515                                  -45.90
#
#       NASDAQ Computer Historical Data_diffHL  sentiment score  bull score  \
# 0                                      11.12         0.791034    0.051724
# 1                                      11.72         0.781659    0.018519
# 2                                      10.60         0.762075    0.016949
# 3                                       7.71         1.106518    0.000000
# 4                                      18.21         0.792473    0.022727
# ...                                      ...              ...         ...
# 2511                                   81.40         1.029903    0.116418
# 2512                                  143.66         1.090501    0.074184
# 2513                                   84.34         0.948187    0.133333
# 2514                                   76.11         1.015531    0.116959
# 2515                                  170.45              NaN         NaN
#
#       bear score
# 0       0.068966
# 1       0.018519
# 2       0.067797
# 3       0.058824
# 4       0.113636
# ...          ...
# 2511    0.077612
# 2512    0.068249
# 2513    0.000000
# 2514    0.043860
# 2515         NaN
#
# [2516 rows x 536 columns]

# %%
df.info(max_cols=600)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2516 entries, 0 to 2515
# Data columns (total 536 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Date                                                       2516 non-null   datetime64[ns]
#  1   GS_Price                                                   2516 non-null   float64
#  2   GS_Open                                                    2516 non-null   float64
#  3   GS_High                                                    2516 non-null   float64
#  4   GS_Low                                                     2516 non-null   float64
#  5   GS_Vol.                                                    2516 non-null   float64
#  6   GS_Change %                                                2516 non-null   float64
#  7   GS_diffCO                                                  2516 non-null   float64
#  8   GS_diffHL                                                  2516 non-null   float64
#  9   FTSE 100 Historical Data_Price                             2516 non-null   float64
#  10  FTSE 100 Historical Data_Open                              2516 non-null   float64
#  11  FTSE 100 Historical Data_High                              2516 non-null   float64
#  12  FTSE 100 Historical Data_Low                               2516 non-null   float64
#  13  FTSE 100 Historical Data_Vol.                              2516 non-null   float64
#  14  FTSE 100 Historical Data_Change %                          2516 non-null   float64
#  15  FTSE 100 Historical Data_diffCO                            2516 non-null   float64
#  16  FTSE 100 Historical Data_diffHL                            2516 non-null   float64
#  17  Dow Jones Industrial Average Historical Data_Price         2516 non-null   float64
#  18  Dow Jones Industrial Average Historical Data_Open          2516 non-null   float64
#  19  Dow Jones Industrial Average Historical Data_High          2516 non-null   float64
#  117 Bitcoin Historical Data_Price                              2516 non-null   float64
#  118 Bitcoin Historical Data_Open                               2516 non-null   float64
#  119 Bitcoin Historical Data_High                               2516 non-null   float64
#  120 Bitcoin Historical Data_Low                                2516 non-null   float64
#  121 Bitcoin Historical Data_Vol.                               2516 non-null   float64
#  122 Bitcoin Historical Data_Change %                           2516 non-null   float64
#  123 Bitcoin Historical Data_diffCO                             2516 non-null   float64
#  124 Bitcoin Historical Data_diffHL                             2516 non-null   float64
#  125 RTSI Historical Data_Price                                 2516 non-null   float64
#  126 RTSI Historical Data_Open                                  2516 non-null   float64
#  127 RTSI Historical Data_High                                  2516 non-null   float64
#  128 RTSI Historical Data_Low                                   2516 non-null   float64
#  129 RTSI Historical Data_Change %                              2516 non-null   float64
#  130 RTSI Historical Data_diffCO                                2516 non-null   float64
#  131 RTSI Historical Data_diffHL                                2516 non-null   float64
#  132 S&P_TSX Composite Historical Data_Price                    2516 non-null   float64
#  133 S&P_TSX Composite Historical Data_Open                     2516 non-null   float64
#  134 S&P_TSX Composite Historical Data_High                     2516 non-null   float64
#  135 S&P_TSX Composite Historical Data_Low                      2516 non-null   float64
#  136 S&P_TSX Composite Historical Data_Vol.                     2516 non-null   float64
#  137 S&P_TSX Composite Historical Data_Change %                 2516 non-null   float64
#  138 S&P_TSX Composite Historical Data_diffCO                   2516 non-null   float64
#  139 S&P_TSX Composite Historical Data_diffHL                   2516 non-null   float64
#  140 S&P_ASX 200 Historical Data_Price                          2516 non-null   float64
#  141 S&P_ASX 200 Historical Data_Open                           2516 non-null   float64
#  142 S&P_ASX 200 Historical Data_High                           2516 non-null   float64
#  143 S&P_ASX 200 Historical Data_Low                            2516 non-null   float64
#  144 S&P_ASX 200 Historical Data_Vol.                           2516 non-null   float64
#  145 S&P_ASX 200 Historical Data_Change %                       2516 non-null   float64
#  146 S&P_ASX 200 Historical Data_diffCO                         2516 non-null   float64
#  147 S&P_ASX 200 Historical Data_diffHL                         2516 non-null   float64
#  148 MS Historical Data_Price                                   2516 non-null   float64
#  149 MS Historical Data_Open                                    2516 non-null   float64
#  150 MS Historical Data_High                                    2516 non-null   float64
#  151 MS Historical Data_Low                                     2516 non-null   float64
#  152 MS Historical Data_Vol.                                    2516 non-null   float64
#  153 MS Historical Data_Change %                                2516 non-null   float64
#  154 MS Historical Data_diffCO                                  2516 non-null   float64
#  155 MS Historical Data_diffHL                                  2516 non-null   float64
#  156 USD_JPY Historical Data_Price                              2516 non-null   float64
#  157 USD_JPY Historical Data_Open                               2516 non-null   float64
#  158 USD_JPY Historical Data_High                               2516 non-null   float64
#  159 USD_JPY Historical Data_Low                                2516 non-null   float64
#  160 USD_JPY Historical Data_Change %                           2516 non-null   float64
#  161 USD_JPY Historical Data_diffCO                             2516 non-null   float64
#  162 USD_JPY Historical Data_diffHL                             2516 non-null   float64
#  163 GBP_USD Historical Data_Price                              2516 non-null   float64
#  164 GBP_USD Historical Data_Open                               2516 non-null   float64
#  165 GBP_USD Historical Data_High                               2516 non-null   float64
#  166 GBP_USD Historical Data_Low                                2516 non-null   float64
#  167 GBP_USD Historical Data_Change %                           2516 non-null   float64
#  168 GBP_USD Historical Data_diffCO                             2516 non-null   float64
#  169 GBP_USD Historical Data_diffHL                             2516 non-null   float64
#  170 NYSE Composite Historical Data_Price                       2516 non-null   float64
#  171 NYSE Composite Historical Data_Open                        2516 non-null   float64
#  172 NYSE Composite Historical Data_High                        2516 non-null   float64
#  173 NYSE Composite Historical Data_Low                         2516 non-null   float64
#  174 NYSE Composite Historical Data_Change %                    2516 non-null   float64
#  175 NYSE Composite Historical Data_diffCO                      2516 non-null   float64
#  176 NYSE Composite Historical Data_diffHL                      2516 non-null   float64
#  177 Brent Oil Futures Historical Data_Price                    2516 non-null   float64
#  178 Brent Oil Futures Historical Data_Open                     2516 non-null   float64
#  179 Brent Oil Futures Historical Data_High                     2516 non-null   float64
#  180 Brent Oil Futures Historical Data_Low                      2516 non-null   float64
#  181 Brent Oil Futures Historical Data_Vol.                     2516 non-null   float64
#  182 Brent Oil Futures Historical Data_Change %                 2516 non-null   float64
#  183 Brent Oil Futures Historical Data_diffCO                   2516 non-null   float64
#  184 Brent Oil Futures Historical Data_diffHL                   2516 non-null   float64
#  185 MSFT Historical Data_Price                                 2516 non-null   float64
#  186 MSFT Historical Data_Open                                  2516 non-null   float64
#  187 MSFT Historical Data_High                                  2516 non-null   float64
#  188 MSFT Historical Data_Low                                   2516 non-null   float64
#  189 MSFT Historical Data_Vol.                                  2516 non-null   float64
#  190 MSFT Historical Data_Change %                              2516 non-null   float64
#  191 MSFT Historical Data_diffCO                                2516 non-null   float64
#  192 MSFT Historical Data_diffHL                                2516 non-null   float64
#  193 USD_RUB Historical Data_Price                              2516 non-null   float64
#  194 USD_RUB Historical Data_Open                               2516 non-null   float64
#  195 USD_RUB Historical Data_High                               2516 non-null   float64
#  196 USD_RUB Historical Data_Low                                2516 non-null   float64
#  197 USD_RUB Historical Data_Change %                           2516 non-null   float64
#  198 USD_RUB Historical Data_diffCO                             2516 non-null   float64
#  199 USD_RUB Historical Data_diffHL                             2516 non-null   float64
#  200 EUR_USD Historical Data_Price                              2516 non-null   float64
#  201 EUR_USD Historical Data_Open                               2516 non-null   float64
#  202 EUR_USD Historical Data_High                               2516 non-null   float64
#  203 EUR_USD Historical Data_Low                                2516 non-null   float64
#  204 EUR_USD Historical Data_Change %                           2516 non-null   float64
#  205 EUR_USD Historical Data_diffCO                             2516 non-null   float64
#  206 EUR_USD Historical Data_diffHL                             2516 non-null   float64
#  207 EUR_RUB Historical Data_Price                              2516 non-null   float64
#  208 EUR_RUB Historical Data_Open                               2516 non-null   float64
#  209 EUR_RUB Historical Data_High                               2516 non-null   float64
#  210 EUR_RUB Historical Data_Low                                2516 non-null   float64
#  211 EUR_RUB Historical Data_Change %                           2516 non-null   float64
#  212 EUR_RUB Historical Data_diffCO                             2516 non-null   float64
#  213 EUR_RUB Historical Data_diffHL                             2516 non-null   float64
#  214 MSCI Historical Data_Price                                 2516 non-null   float64
#  215 MSCI Historical Data_Open                                  2516 non-null   float64
#  216 MSCI Historical Data_High                                  2516 non-null   float64
#  217 MSCI Historical Data_Low                                   2516 non-null   float64
#  218 MSCI Historical Data_Vol.                                  2516 non-null   float64
#  219 MSCI Historical Data_Change %                              2516 non-null   float64
#  220 MSCI Historical Data_diffCO                                2516 non-null   float64
#  221 MSCI Historical Data_diffHL                                2516 non-null   float64
#  222 ux-(украина)                                               2516 non-null   float64
#  223 золото-(лондон)                                            2516 non-null   float64
#  224 ifx-cbonds                                                 2516 non-null   float64
#  225 серебро-(лондон)                                           2516 non-null   float64
#  226 платина-(лондон)                                           2516 non-null   float64
#  227 палладий-(лондон)                                         2516 non-null   float64
#  228 kase-(казахстан)                                           2516 non-null   float64
#  229 LIBOR USD_ON                                               2516 non-null   float64
#  230 LIBOR USD_1W                                               2516 non-null   float64
#  231 LIBOR USD_1M                                               2516 non-null   float64
#  232 LIBOR USD_2M                                               2516 non-null   float64
#  233 LIBOR USD_3M                                               2516 non-null   float64
#  234 LIBOR USD_6M                                               2516 non-null   float64
#  235 LIBOR USD_12M                                              2516 non-null   float64
#  236 LIBOR EUR_ON                                               2516 non-null   float64
#  237 LIBOR EUR_1W                                               2516 non-null   float64
#  238 LIBOR EUR_1M                                               2516 non-null   float64
#  239 LIBOR EUR_2M                                               2516 non-null   float64
#  240 LIBOR EUR_3M                                               2516 non-null   float64
#  241 LIBOR EUR_6M                                               2516 non-null   float64
#  242 LIBOR EUR_12M                                              2516 non-null   float64
#  243 LIBOR GBP_ON                                               2516 non-null   float64
#  244 LIBOR GBP_1W                                               2516 non-null   float64
#  245 LIBOR GBP_1M                                               2516 non-null   float64
#  246 LIBOR GBP_2M                                               2516 non-null   float64
#  247 LIBOR GBP_3M                                               2516 non-null   float64
#  248 LIBOR GBP_6M                                               2516 non-null   float64
#  249 LIBOR GBP_12M                                              2516 non-null   float64
#  250 LIBOR CHF_ON                                               2516 non-null   float64
#  251 LIBOR CHF_1W                                               2516 non-null   float64
#  252 LIBOR CHF_1M                                               2516 non-null   float64
#  253 LIBOR CHF_2M                                               2516 non-null   float64
#  254 LIBOR CHF_3M                                               2516 non-null   float64
#  255 LIBOR CHF_6M                                               2516 non-null   float64
#  256 LIBOR CHF_12M                                              2516 non-null   float64
#  257 LIBOR JPY_ON                                               2516 non-null   float64
#  258 LIBOR JPY_1W                                               2516 non-null   float64
#  259 LIBOR JPY_1M                                               2516 non-null   float64
#  260 LIBOR JPY_2M                                               2516 non-null   float64
#  261 LIBOR JPY_3M                                               2516 non-null   float64
#  262 LIBOR JPY_6M                                               2516 non-null   float64
#  263 LIBOR JPY_12M                                              2516 non-null   float64
#  264 Dow Jones Basic Materials Historical Data_Price            2516 non-null   float64
#  265 Dow Jones Basic Materials Historical Data_Open             2516 non-null   float64
#  266 Dow Jones Basic Materials Historical Data_High             2516 non-null   float64
#  267 Dow Jones Basic Materials Historical Data_Low              2516 non-null   float64
#  268 Dow Jones Basic Materials Historical Data_Vol.             2516 non-null   float64
#  534 bull score                                                 2514 non-null   float64
#  535 bear score                                                 2514 non-null   float64
# dtypes: datetime64[ns](1), float64(535)
# memory usage: 10.3 MB

# %%
cols_to_work =['Date', KEY, 'Bitcoin Historical Data_Price', 'USD_JPY Historical Data_Price', 'GBP_USD Historical Data_Price',
               'Brent Oil Futures Historical Data_Price', 'EUR_USD Historical Data_Price',   'Dow Jones Basic Materials Historical Data_Price', 
               'NYSE Energy Historical Data_Price', 'S&P 500 Materials Historical Data_Price', 'S&P 500 Real Estate Historical Data_Price'] 
#'LIBOR USD_ON' ,  'LIBOR USD_1W' ,  'LIBOR USD_1M' , 'LIBOR USD_2M', 'LIBOR USD_3M', 'LIBOR USD_6M', 'LIBOR USD_12M',

# %%
df = df.interpolate(method ='linear', limit_direction ='both', limit = 50)

# %%
#cols = ['Date', KEY] + list(best_features_z.columns) +['d1', 'd2', 'd3']#list(best_features_n.columns)
cols = ['Date', KEY]   + ['sentiment score',	'bull score',	'bear score']  #list(best_features_n.columns)  ['sentiment score',	'bull score',	'bear score'] 
cols
# Out:
# ['Date',
#  'Bitcoin Historical Data_Price',
#  'sentiment score',
#  'bull score',
#  'bear score']

# %%
data = df[cols]
mask = (data['Date'] <='2021-04-19') 
data = data.loc[mask]
data.info()
data  = data.fillna(0)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2516 entries, 0 to 2515
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Date                           2516 non-null   datetime64[ns]
#  1   Bitcoin Historical Data_Price  2516 non-null   float64
#  2   sentiment score                2516 non-null   float64
#  3   bull score                     2516 non-null   float64
#  4   bear score                     2516 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 117.9 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2516 entries, 0 to 2515
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Date                           2516 non-null   datetime64[ns]
#  1   Bitcoin Historical Data_Price  2516 non-null   float64
#  2   sentiment score                2516 non-null   float64
#  3   bull score                     2516 non-null   float64
#  4   bear score                     2516 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 117.9 KB

# %%
_std =data[KEY].std()
_mean = data[KEY].mean()
_min = data[KEY].min()
_max = data[KEY].max()
_mean, _std, _max, _min
# Out:
# (4557.69745627981, 8877.515790564115, 63540.9, 1.1)

# %%
zn_train_df = z_df(data, 1, [KEY, 'Date'])#, no_cols=['d1', 'd2'])
zn_train_df.info()
z_y_key = 'z_'+KEY
z_y_key
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2516 entries, 0 to 2515
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date                             2516 non-null   datetime64[ns]
#  1   Bitcoin Historical Data_Price    2516 non-null   float64
#  2   sentiment score                  2516 non-null   float64
#  3   bull score                       2516 non-null   float64
#  4   bear score                       2516 non-null   float64
#  5   z_Bitcoin Historical Data_Price  2516 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 137.6 KB
# 'z_Bitcoin Historical Data_Price'

# %%
# f_cols = ['price','sentiment score','bull score', 'bear score']
#ifft_cols = list(best_features_z.columns) +['d1', 'd2', 'd3']#[]#['sentiment score','bull score', 'bear score']+ ['d1', 'd2'] 
ifft_cols =  [z_y_key]+['sentiment score',	'bull score',	'bear score'] # ['sentiment score','bull score', 'bear score'] 
list_fft_comp = [32]#[16, 64]
key_for_d =  z_y_key + '_' + str(max(list_fft_comp)) + '_ifft'
key_for_d
# Out:
# 'z_Bitcoin Historical Data_Price_32_ifft'

# %%
for key_ in ifft_cols:  
   zn_train_df = ifft_add_columns(zn_train_df, key_, list_fft_comp, n_adds =1000)
zn_train_df = zn_train_df.drop(columns=ifft_cols)
zn_train_df.info()
# Out:
# (2516, 7)
# (2516, 8)
# (2516, 9)
# (2516, 10)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2516 entries, 0 to 2515
# Data columns (total 6 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Date                                     2516 non-null   datetime64[ns]
#  1   Bitcoin Historical Data_Price            2516 non-null   float64
#  2   z_Bitcoin Historical Data_Price_32_ifft  2516 non-null   float64
#  3   sentiment score_32_ifft                  2516 non-null   float64
#  4   bull score_32_ifft                       2516 non-null   float64
#  5   bear score_32_ifft                       2516 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 137.6 KB

# %%
zn_train_df['d1'] = (shift_from_end(zn_train_df[key_for_d],1)-zn_train_df[key_for_d])
zn_train_df['d2'] =(shift_from_end(zn_train_df['d1'],1)-zn_train_df['d1'])
#zn_train_df['d3'] =(shift_from_end(zn_train_df['d2'],1)-zn_train_df['d2'])
zn_train_df = z_df(zn_train_df, cols=['d1', 'd2'])#, 'd3'])

# %%
for key_ in ['d1', 'd2']:  
   zn_train_df = ifft_add_columns(zn_train_df, key_, list_fft_comp, n_adds =1000)
zn_train_df = zn_train_df.drop(columns=['d1', 'd2'])
# Out:
# (2516, 9)
# (2516, 10)

# %%
#zn_train_df = z_df(zn_train_df, 1, [KEY, 'Date'])#, no_cols=['d1', 'd2'])
zn_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2516 entries, 0 to 2515
# Data columns (total 8 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Date                                     2516 non-null   datetime64[ns]
#  1   Bitcoin Historical Data_Price            2516 non-null   float64
#  2   z_Bitcoin Historical Data_Price_32_ifft  2516 non-null   float64
#  3   sentiment score_32_ifft                  2516 non-null   float64
#  4   bull score_32_ifft                       2516 non-null   float64
#  5   bear score_32_ifft                       2516 non-null   float64
#  6   d1_32_ifft                               2516 non-null   float64
#  7   d2_32_ifft                               2516 non-null   float64
# dtypes: datetime64[ns](1), float64(7)
# memory usage: 176.9 KB

# %%
zn_train_df['y'] = (zn_train_df[KEY]-_mean)/_std
#zn_train_df = zn_train_df.drop(columns=[z_y_key])

# %%
zn_train_df
# Out:
#            Date  Bitcoin Historical Data_Price  \
# 0    2011-04-19                            1.2
# 1    2011-04-20                            1.1
# 2    2011-04-21                            1.2
# 3    2011-04-25                            1.6
# 4    2011-04-26                            1.8
# ...         ...                            ...
# 2511 2021-04-13                        63540.9
# 2512 2021-04-14                        62980.4
# 2513 2021-04-15                        63216.0
# 2514 2021-04-16                        61379.7
# 2515 2021-04-19                        55646.1
#
#       z_Bitcoin Historical Data_Price_32_ifft  sentiment score_32_ifft  \
# 0                                    0.511110                 0.456773
# 1                                    0.511372                 0.454985
# 2                                    0.511637                 0.453022
# 3                                    0.511906                 0.450884
# 4                                    0.512179                 0.448570
# ...                                       ...                      ...
# 2511                                 3.173655                 0.354532
# 2512                                 3.100917                 0.335568
# 2513                                 3.027005                 0.316516
# 2514                                 2.951987                 0.297392
# 2515                                 2.875933                 0.278210
#
#       bull score_32_ifft  bear score_32_ifft  d1_32_ifft  d2_32_ifft         y
# 0               0.142075            0.101205    0.111154    0.014902 -0.513263
# 1               0.125766            0.098809    0.110193    0.015801 -0.513274
# 2               0.109367            0.096635    0.109155    0.016675 -0.513263
# 3               0.092888            0.094691    0.108047    0.017522 -0.513218
# 4               0.076341            0.092984    0.106878    0.018340 -0.513195
# ...                  ...                 ...         ...         ...       ...
# 2511            1.102051            0.427683    2.373519    0.168345  6.644111
# 2512            1.092506            0.423081    2.396615    0.144978  6.580974
# 2513            1.082711            0.418440    2.416473    0.121713  6.607513
# 2514            1.072678            0.413763    2.433106    0.098592  6.400665
# 2515            1.062419            0.409057    2.446529    0.075667  5.754808
#
# [2516 rows x 9 columns]

# %%
zn_train_df.info(max_cols=600)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2516 entries, 0 to 2515
# Data columns (total 9 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Date                                     2516 non-null   datetime64[ns]
#  1   Bitcoin Historical Data_Price            2516 non-null   float64
#  2   z_Bitcoin Historical Data_Price_32_ifft  2516 non-null   float64
#  3   sentiment score_32_ifft                  2516 non-null   float64
#  4   bull score_32_ifft                       2516 non-null   float64
#  5   bear score_32_ifft                       2516 non-null   float64
#  6   d1_32_ifft                               2516 non-null   float64
#  7   d2_32_ifft                               2516 non-null   float64
#  8   y                                        2516 non-null   float64
# dtypes: datetime64[ns](1), float64(8)
# memory usage: 196.6 KB

# %%
plt.figure(figsize=(14, 7), dpi=100)
for_gr = norm_df(zn_train_df, no_cols=['Date'])
ifft_res = {}
for key_ in for_gr.columns[2:]:
    plt.plot(for_gr[key_], label=key_)
plt.title('Figure #:' + KEY)
plt.legend()
plt.show()

# %%
window = 64
f = 32

# %%
# x = []
# y = []
# i = 0
# while window + i + f + 1  < zn_train_df.shape[0]:
#     df_x = zn_train_df.iloc[i:window+i, 2:zn_train_df.shape[1]].reset_index(drop = 1)# - ntrain_df.iloc[i:window +i, 2:].reset_index(drop = 1)
#     x.append(df_x.to_numpy())
#     df_y = zn_train_df.iloc[window+i+1:window+i+f+1, zn_train_df.shape[1]-1].reset_index(drop = 1)
#     y.append(df_y.to_numpy())
#     i += 1
# x = np.array(x)
# x.shape

# %%
x = []
y = []
i = 0
while window + i + 1  < zn_train_df.shape[0]-f:
    df_x = zn_train_df.iloc[i:window+i, 2:zn_train_df.shape[1]].reset_index(drop = 1)# - ntrain_df.iloc[i:window +i, 2:].reset_index(drop = 1)
    x.append(df_x.to_numpy())
    df_y = ((df.iloc[window+i+1:window+i+f+1, list(df.columns).index(KEY)].reset_index(drop = 1))-_mean)/_std
    #print(df_y)
    y.append(df_y.to_numpy())
    #print(df_y.to_numpy().shape)
    i += 1
x = np.array(x)
y = np.array(y)
print(x.shape, y.shape)
x_c = np.reshape(x, (-1, x.shape[1], x.shape[2], 1))
x_l = np.reshape(x, (-1, x.shape[1], x.shape[2]))
print(x_c.shape, x_l.shape)
y_c = np.reshape(y, (-1, f, 1))
y_l = np.reshape(y, (-1, f))
y_c.shape, y_l.shape, y.shape
# Out:
# (2419, 64, 7) (2419, 32)
# (2419, 64, 7, 1) (2419, 64, 7)
# ((2419, 32, 1), (2419, 32), (2419, 32))

# %%
# ПРЕДИКТ !!!
x = []
i = 0
while window + i + 1  < zn_train_df.shape[0]:
    df_x = zn_train_df.iloc[i:window+i, 2:zn_train_df.shape[1]].reset_index(drop = 1)# - ntrain_df.iloc[i:window +i, 2:].reset_index(drop = 1)
    x.append(df_x.to_numpy())
    #print(df_y.to_numpy().shape)
    i += 1
x = np.array(x)
print(x.shape, y.shape)
x_c = np.reshape(x, (-1, x.shape[1], x.shape[2], 1))
x_l = np.reshape(x, (-1, x.shape[1], x.shape[2]))
x_c.shape, x_l.shape
# Out:
# (2451, 64, 7) (2451,)
# ((2451, 64, 7, 1), (2451, 64, 7))

# %%
#i = 31
#str(list(dfn['GS_High'][i+1:window+i+1]*(_max-_min)+_min))
#x[31,:,0]*(_max-_min)+_min

# %%
str(list(data[KEY][window+1:window+f+1]))
# Out:
# '[13.7, 14.1, 13.9, 13.9, 13.5, 13.5, 13.1, 12.1, 9.3, 10.8, 9.8, 7.8, 10.0, 10.0, 9.5, 9.5, 11.1, 11.0, 10.9, 10.8, 11.6, 10.9, 10.9, 10.9, 9.7, 8.2, 9.0, 8.8, 8.2, 8.2, 8.6, 6.9]'

# %%
pred_test = y[0] * _std + _mean
pred_test
# Out:
# array([13.7, 14.1, 13.9, 13.9, 13.5, 13.5, 13.1, 12.1,  9.3, 10.8,  9.8,
#         7.8, 10. , 10. ,  9.5,  9.5, 11.1, 11. , 10.9, 10.8, 11.6, 10.9,
#        10.9, 10.9,  9.7,  8.2,  9. ,  8.8,  8.2,  8.2,  8.6,  6.9])

# %%
# pred_test = y[0:1] * (_max - _min) + _min
# pred_test

# %%
#pred2[0:1,0:1].flatten() *(_max - _min) + _min

# %% [markdown]
# ## Пробуем LSTM

# %%
N = y.shape[0]-f# 2415 разбиваем на train и val 
N
# Out:
# 2387

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import concatenate, Input, Dense, Dropout, BatchNormalization, Flatten, Conv1D, Conv2D, LSTM
from tensorflow.keras.models import Sequential, Model

# %%
lstm = Sequential(name="LSTM")
lstm.add(LSTM(1024, recurrent_regularizer='L2' , input_shape = (x.shape[1], x.shape[2]), return_sequences="True"))
lstm.add(LSTM(1024, recurrent_regularizer='L2')) #, return_sequences="True"))
#model.add(Conv1D(64, 3, activation="linear"))
# model.add(Conv1D(64, 3, activation="linear"))
# model.add(Flatten())
# model.add(Dense(16, activation="linear"))
lstm.add(Dense(y.shape[1], activation="linear"))

lstm.compile(loss="mae", optimizer="adam", metrics=['mae'])
lstm.summary()
# Out:
# Model: "LSTM"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 64, 1024)          4227072
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 1024)              8392704
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                32800
# =================================================================
# Total params: 12,652,576
# Trainable params: 12,652,576
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm.load_weights(W_PATH + 'lstm_BITC_070121_1000_3_1024_1024_y_ifft16-64(snt+y+d1+d2)_16-32_0.5160900354385376')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-63ab2d9163f7> in <module>()
# ----> 1 lstm.load_weights(W_PATH + 'lstm_BITC_070121_1000_3_1024_1024_y_ifft16-64(snt+y+d1+d2)_16-32_0.5160900354385376')
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2295     filepath, save_format = _detect_save_format(filepath)
#    2296     if save_format == 'tf':
# -> 2297       status = self._trackable_saver.restore(filepath, options)
#    2298       if by_name:
#    2299         raise NotImplementedError(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/util.py in restore(self, save_path, options)
#    1337         options=options)
#    1338     base.CheckpointPosition(
# -> 1339         checkpoint=checkpoint, proto_id=0).restore(self._graph_view.root)
#    1340
#    1341     # Attached dependencies are not attached to the root, so should be restored
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/base.py in restore(self, trackable)
#     256         # This object's correspondence with a checkpointed object is new, so
#     257         # process deferred restorations for it and its dependencies.
# --> 258         restore_ops = trackable._restore_from_checkpoint_position(self)  # pylint: disable=protected-access
#     259         if restore_ops:
#     260           self._checkpoint.new_restore_ops(restore_ops)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/base.py in _restore_from_checkpoint_position(self, checkpoint_position)
#     976     restore_ops.extend(
#     977         current_position.checkpoint.restore_saveables(
# --> 978             tensor_saveables, python_saveables))
#     979     return restore_ops
#     980
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/util.py in restore_saveables(self, tensor_saveables, python_saveables)
#     307              "expecting %s") % (tensor_saveables.keys(), validated_names))
#     308       new_restore_ops = functional_saver.MultiDeviceSaver(
# --> 309           validated_saveables).restore(self.save_path_tensor, self.options)
#     310       if not context.executing_eagerly():
#     311         for name, restore_op in sorted(new_restore_ops.items()):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/saving/functional_saver.py in restore(self, file_prefix, options)
#     337       restore_ops = tf_function_restore()
#     338     else:
# --> 339       restore_ops = restore_fn()
#     340
#     341     for callback in self._after_restore_callbacks:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/saving/functional_saver.py in restore_fn()
#     321       for device, saver in sorted(self._single_device_savers.items()):
#     322         with ops.device(device):
# --> 323           restore_ops.update(saver.restore(file_prefix, options))
#     324
#     325       return restore_ops
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/saving/functional_saver.py in restore(self, file_prefix, options)
#     114                                           structured_restored_tensors):
#     115       restore_ops[saveable.name] = saveable.restore(
# --> 116           restored_tensors, restored_shapes=None)
#     117     return restore_ops
#     118
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/saving/saveable_object_util.py in restore(self, restored_tensors, restored_shapes)
#     130       restored_tensor = array_ops.identity(restored_tensor)
#     131       return resource_variable_ops.shape_safe_assign_variable_handle(
# --> 132           self.handle_op, self._var_shape, restored_tensor)
#     133
#     134
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py in shape_safe_assign_variable_handle(handle, shape, value, name)
#     306   with _handle_graph(handle):
#     307     value_tensor = ops.convert_to_tensor(value)
# --> 308   shape.assert_is_compatible_with(value_tensor.shape)
#     309   return gen_resource_variable_ops.assign_variable_op(
#     310       handle, value_tensor, name=name)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/tensor_shape.py in assert_is_compatible_with(self, other)
#    1159     """
#    1160     if not self.is_compatible_with(other):
# -> 1161       raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#    1162
#    1163   def most_specific_compatible_shape(self, other):
#
# ValueError: Shapes (7, 4096) and (13, 4096) are incompatible

# %%
callback = EarlyStopping(monitor='val_mae', mode = 'min',  patience=15,  restore_best_weights=1, verbose = 1)  # patience=100
history = lstm.fit(
    x_l[:N], y_l[:N],
    epochs=200,
    validation_data=(x_l[N:], y_l[N:]),
    callbacks=[callback])
# Out:
# Epoch 1/200
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 75/75 [==============================] - 9s 78ms/step - loss: 2.9996 - mae: 0.1363 - val_loss: 1.8067 - val_mae: 1.7814
# Epoch 2/200
# 75/75 [==============================] - 5s 71ms/step - loss: 0.0928 - mae: 0.0847 - val_loss: 1.2721 - val_mae: 1.2674
# Epoch 3/200
# 75/75 [==============================] - 5s 72ms/step - loss: 0.0959 - mae: 0.0896 - val_loss: 0.6483 - val_mae: 0.6449
# Epoch 4/200
# 75/75 [==============================] - 5s 70ms/step - loss: 0.0895 - mae: 0.0850 - val_loss: 0.8702 - val_mae: 0.8674
# Epoch 5/200
# 75/75 [==============================] - 5s 69ms/step - loss: 0.0862 - mae: 0.0819 - val_loss: 0.8211 - val_mae: 0.8179
# Epoch 6/200
# 75/75 [==============================] - 5s 68ms/step - loss: 0.0816 - mae: 0.0784 - val_loss: 0.8591 - val_mae: 0.8562
# Epoch 7/200
# 75/75 [==============================] - 5s 67ms/step - loss: 0.0816 - mae: 0.0783 - val_loss: 1.6008 - val_mae: 1.5937
# Epoch 8/200
# 75/75 [==============================] - 5s 66ms/step - loss: 0.0796 - mae: 0.0756 - val_loss: 0.7659 - val_mae: 0.7609
# Epoch 9/200
# 75/75 [==============================] - 5s 65ms/step - loss: 0.0816 - mae: 0.0766 - val_loss: 0.7335 - val_mae: 0.7305
# Epoch 10/200
# 75/75 [==============================] - 5s 65ms/step - loss: 0.0708 - mae: 0.0680 - val_loss: 0.8123 - val_mae: 0.8099
# Epoch 11/200
# 75/75 [==============================] - 5s 65ms/step - loss: 0.0714 - mae: 0.0681 - val_loss: 1.2272 - val_mae: 1.2239
# Epoch 12/200
# 75/75 [==============================] - 5s 65ms/step - loss: 0.0678 - mae: 0.0652 - val_loss: 1.1899 - val_mae: 1.1864
# Epoch 13/200
# 75/75 [==============================] - 5s 65ms/step - loss: 0.0771 - mae: 0.0717 - val_loss: 0.7263 - val_mae: 0.7231
# Epoch 14/200
# 75/75 [==============================] - 5s 65ms/step - loss: 0.0675 - mae: 0.0635 - val_loss: 0.7755 - val_mae: 0.7727
# Epoch 15/200
# 75/75 [==============================] - 5s 65ms/step - loss: 0.0631 - mae: 0.0599 - val_loss: 0.9499 - val_mae: 0.9464
# Epoch 16/200
# 75/75 [==============================] - 5s 66ms/step - loss: 0.0618 - mae: 0.0585 - val_loss: 0.9484 - val_mae: 0.9459
# Epoch 17/200
# 75/75 [==============================] - 5s 66ms/step - loss: 0.0603 - mae: 0.0571 - val_loss: 1.0578 - val_mae: 1.0548
# Epoch 18/200
# 75/75 [==============================] - 5s 66ms/step - loss: 0.0617 - mae: 0.0570 - val_loss: 0.9532 - val_mae: 0.9492
# Restoring model weights from the end of the best epoch.
# Epoch 00018: early stopping

# %%
plt.plot(history.history['mae'][1:], 
         label='Средняя абсолютная ошибка на обучающем наборе')
plt.plot(history.history['val_mae'][1:], 
         label='Средняя абсолютная ошибка на проверочном наборе')
plt.ylabel('Средняя ошибка')
plt.legend()
plt.show()

# %%
evaluate_lstm = lstm.evaluate(x_l[N:], y_l[N:])
# Out:
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6483 - mae: 0.6449

# %%
#lstm.save_weights(W_PATH + 'lstm_BITC_070121_1000_3_1024_1024_y_ifft16-64(snt+y+d1+d2)_16-32_'+str(evaluate_lstm[1]))

# %% [markdown]
# # Пробуем discriminator

# %%
discriminator = keras.Sequential(
    [
        keras.Input(shape=(x.shape[1], x.shape[2], 1)),
        layers.Conv2D(512, (9, 9), strides=(1, 1), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2D(256, (7, 7), strides=(1, 1), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2D(256, (3, 3), strides=(1, 1), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2D(y.shape[1], (3, 3), strides=(1, 1), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.GlobalMaxPooling2D(),
    ],
    name="discriminator",
)

discriminator.summary()
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 64, 7, 512)        41984
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64, 7, 512)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 7, 256)        6422784
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64, 7, 256)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 7, 256)        590080
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 64, 7, 256)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 7, 32)         73760
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 64, 7, 32)         0
# _________________________________________________________________
# global_max_pooling2d_1 (Glob (None, 32)                0
# =================================================================
# Total params: 7,128,608
# Trainable params: 7,128,608
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator.compile(loss="mae", optimizer="adam", metrics=['mae'])

# %%
discriminator.load_weights(W_PATH + 'disc_BITC_070121_1000_3_1024_1024_y_ifft16-64(snt+y+d1+d2)_16-32_0.2068644016981125')

# %%
callback = EarlyStopping(monitor='val_mae', patience=15, restore_best_weights=1, verbose = 1)
history = discriminator.fit(x_c[:N], y_c[:N], epochs=200, batch_size=320, validation_data=(x_c[N:], y_c[N:]), callbacks=[callback])
# Out:
# Epoch 1/200
# 8/8 [==============================] - 13s 2s/step - loss: 0.4388 - mae: 0.4388 - val_loss: 2.5679 - val_mae: 2.5679
# Epoch 2/200
# 8/8 [==============================] - 8s 985ms/step - loss: 0.2445 - mae: 0.2445 - val_loss: 3.1023 - val_mae: 3.1023
# Epoch 3/200
# 8/8 [==============================] - 8s 973ms/step - loss: 0.1388 - mae: 0.1388 - val_loss: 1.8335 - val_mae: 1.8335
# Epoch 4/200
# 8/8 [==============================] - 7s 925ms/step - loss: 0.1217 - mae: 0.1217 - val_loss: 1.2129 - val_mae: 1.2129
# Epoch 5/200
# 8/8 [==============================] - 7s 882ms/step - loss: 0.0981 - mae: 0.0981 - val_loss: 1.1296 - val_mae: 1.1296
# Epoch 6/200
# 8/8 [==============================] - 7s 837ms/step - loss: 0.0806 - mae: 0.0806 - val_loss: 1.3875 - val_mae: 1.3875
# Epoch 7/200
# 8/8 [==============================] - 7s 848ms/step - loss: 0.0855 - mae: 0.0855 - val_loss: 1.4636 - val_mae: 1.4636
# Epoch 8/200
# 8/8 [==============================] - 7s 831ms/step - loss: 0.0728 - mae: 0.0728 - val_loss: 1.4755 - val_mae: 1.4755
# Epoch 9/200
# 8/8 [==============================] - 7s 831ms/step - loss: 0.0633 - mae: 0.0633 - val_loss: 1.1004 - val_mae: 1.1004
# Epoch 10/200
# 8/8 [==============================] - 7s 831ms/step - loss: 0.0604 - mae: 0.0604 - val_loss: 0.9526 - val_mae: 0.9526
# Epoch 11/200
# 8/8 [==============================] - 7s 849ms/step - loss: 0.0596 - mae: 0.0596 - val_loss: 1.1640 - val_mae: 1.1640
# Epoch 12/200
# 8/8 [==============================] - 7s 860ms/step - loss: 0.0583 - mae: 0.0583 - val_loss: 1.3423 - val_mae: 1.3423
# Epoch 13/200
# 8/8 [==============================] - 7s 849ms/step - loss: 0.0574 - mae: 0.0574 - val_loss: 0.9960 - val_mae: 0.9960
# Epoch 14/200
# 8/8 [==============================] - 7s 865ms/step - loss: 0.0574 - mae: 0.0574 - val_loss: 1.1435 - val_mae: 1.1435
# Epoch 15/200
# 8/8 [==============================] - 7s 872ms/step - loss: 0.0549 - mae: 0.0549 - val_loss: 1.3072 - val_mae: 1.3072
# Epoch 16/200
# 8/8 [==============================] - 7s 873ms/step - loss: 0.0532 - mae: 0.0532 - val_loss: 1.3054 - val_mae: 1.3054
# Epoch 17/200
# 8/8 [==============================] - 7s 873ms/step - loss: 0.0619 - mae: 0.0619 - val_loss: 1.2807 - val_mae: 1.2807
# Epoch 18/200
# 8/8 [==============================] - 7s 870ms/step - loss: 0.0660 - mae: 0.0660 - val_loss: 1.1468 - val_mae: 1.1468
# Epoch 19/200
# 8/8 [==============================] - 7s 856ms/step - loss: 0.0666 - mae: 0.0666 - val_loss: 1.2140 - val_mae: 1.2140
# Epoch 20/200
# 8/8 [==============================] - 7s 851ms/step - loss: 0.0543 - mae: 0.0543 - val_loss: 1.3098 - val_mae: 1.3098
# Epoch 21/200
# 8/8 [==============================] - 7s 852ms/step - loss: 0.0559 - mae: 0.0559 - val_loss: 1.2883 - val_mae: 1.2883
# Epoch 22/200
# 8/8 [==============================] - 7s 843ms/step - loss: 0.0535 - mae: 0.0535 - val_loss: 1.4787 - val_mae: 1.4787
# Epoch 23/200
# 8/8 [==============================] - 7s 860ms/step - loss: 0.0472 - mae: 0.0472 - val_loss: 1.3935 - val_mae: 1.3935
# Epoch 24/200
# 8/8 [==============================] - 7s 856ms/step - loss: 0.0520 - mae: 0.0520 - val_loss: 1.4474 - val_mae: 1.4474
# Epoch 25/200
# 8/8 [==============================] - 7s 858ms/step - loss: 0.0489 - mae: 0.0489 - val_loss: 1.1904 - val_mae: 1.1904
# Restoring model weights from the end of the best epoch.
# Epoch 00025: early stopping

# %%
plt.plot(history.history['mae'][1:], 
         label='Средняя абсолютная ошибка на обучающем наборе')
plt.plot(history.history['val_mae'][1:], 
         label='Средняя абсолютная ошибка на проверочном наборе')
plt.ylabel('Средняя ошибка')
plt.legend()
plt.show()

# %%
evaluate_d = discriminator.evaluate(x_c[N:], y_c[N:])
# Out:
# 1/1 [==============================] - 0s 49ms/step - loss: 0.9526 - mae: 0.9526

# %%
discriminator.save_weights(W_PATH + 'disc_b_BITC_070121_1000_3_1024_1024_y_ifft16-64(snt+y+d1+d2)_16-32_'+str(evaluate_d[1]))

# %%
def add_shift(xs, n):
    xs = xs.flatten()
    e = np.empty(n)
    e[:n] = np.nan 
    if n >= 0:
        e = np.append(e, xs, axis = 0)
    return e

# %%
# Напоминалка
x_c.shape, data.shape, window, f, np.array(df[KEY]).shape, np.array(df[KEY]).shape[0] - window
# Out:
# ((2419, 64, 7, 1), (2516, 5), 64, 32, (2516,), 2452)

# %%
N = y.shape[0]-2*window # старт отображения в масштабе x (сдвиг на window)
K = zn_train_df.shape[0]
pred = discriminator.predict(x_c[N:K])* _std + _mean #* (_max - _min) + _min
pred2 = lstm.predict(x_l[N:K])* _std + _mean
y_plot = y[N:K, 0:1].flatten()* _std + _mean
print(pred.min(),  pred.max(), pred2.min(), pred2.max(), y_plot.min(), y_plot.max())
print(add_shift(pred[:,0:1],1).min(),  add_shift(pred[:,0:1],1).max(), add_shift(pred2[:,0:1],1).min(), add_shift(pred2[:,0:1],1).max(), y_plot.min(), y_plot.max())
pred.shape, pred2.shape, y_plot.shape
Y = np.array(df[KEY][window + N +1:])#window + K:])# + 2:])#window + K + 2])
# Out:
# 9906.84 54750.414 10207.053 67356.53 10126.6 55906.600000000006
# nan nan nan nan 10126.6 55906.600000000006

# %% [markdown]
# # График по итогам обучения

# %%
plt.figure(figsize=(24,12))
plt.grid('on')

plt.plot(add_shift(pred[:,0:1],1), label='CONV_1', alpha = 0.5)
# plt.plot(add_shift(pred[:,1:2],2), label='CONV_2', alpha = 0.5)
# plt.plot(add_shift(pred[:,2:3],3), label='CONV_3', alpha = 0.5)
plt.plot(add_shift(pred[:,31:32],31), label='CONV_32', alpha = 0.5)

plt.plot(add_shift(pred2[:,0:1],1), label='LSTM_1', alpha = 0.7)
# plt.plot(add_shift(pred2[:,1:2],2), label='LSTM_2', alpha = 0.7)
# plt.plot(add_shift(pred2[:,2:3],3), label='LSTM_3', alpha = 0.7)
plt.plot(add_shift(pred2[:,31:32],31), label='LSTM_32', alpha = 0.7)

plt.plot(Y, label='data', alpha =0.9, color = 'blue')
plt.plot(y_plot, label='y_plot', alpha =1, color = 'red')

# plt.plot(add_shift(pred_yf_cov[:,0:1],  x_c.shape[0]-N), label='CONV_1_xf', alpha = 0.5)
# plt.plot(add_shift(pred_yf_cov[:,31:32],  x_c.shape[0]-N+f), label='CONV_32_xf', alpha = 0.5)

# plt.plot(add_shift(pred2_yf[:,0:1], x_l.shape[0]-N), label='lstm_1_xf', alpha = 0.5)
# plt.plot(add_shift(pred2_yf[:,31:32], x_l.shape[0]-N+f), label='lstm_32_xf', alpha = 0.5)

plt.vlines(zn_train_df.shape[0]-N-1-window- 2*f, 1.05*Y.max(), 0, linestyles='--', label='TrainVal/Test data cut-off', color = 'black')
plt.vlines(zn_train_df.shape[0]-N-1-window - f , 1.05*Y.max(), 0, linestyles='--', label='Last f stop', color = 'green')

plt.xlabel('Время')
plt.ylabel('Значение ')

plt.ylim([0.65*Y.min(), 1.05*Y.max()])

plt.legend()
plt.show()

# %% [markdown]
# # График предсказания

# %%
N = y.shape[0]-2*f  # старт отображения в масштабе x (сдвиг на window)
K = zn_train_df.shape[0]
pred = discriminator.predict(x_c[N:K])* _std + _mean #* (_max - _min) + _min
pred2 = lstm.predict(x_l[N:K])* _std + _mean
pred.shape, pred2.shape
Y = np.array(df[KEY][window + N +1:])#window + K:])# + 2:])#window + K + 2])

# %%
plt.figure(figsize=(24,12))
plt.grid('on')

plt.plot(add_shift(pred[:,0:1],1), label='CONV_1', alpha = 0.5)
# plt.plot(add_shift(pred[:,1:2],2), label='CONV_2', alpha = 0.5)
# plt.plot(add_shift(pred[:,2:3],3), label='CONV_3', alpha = 0.5)
plt.plot(add_shift(pred[:,31:32],31), label='CONV_32', alpha = 0.5)

plt.plot(add_shift(pred2[:,0:1],1), label='LSTM_1', alpha = 0.7)
# plt.plot(add_shift(pred2[:,1:2],2), label='LSTM_2', alpha = 0.7)
# plt.plot(add_shift(pred2[:,2:3],3), label='LSTM_3', alpha = 0.7)
plt.plot(add_shift(pred2[:,31:32],31), label='LSTM_32', alpha = 0.7)

plt.plot(Y, label='data', alpha =0.9, color = 'blue')
plt.plot(y_plot, label='y_plot', alpha =1, color = 'red')

# plt.plot(add_shift(pred_yf_cov[:,0:1],  x_c.shape[0]-N), label='CONV_1_xf', alpha = 0.5)
# plt.plot(add_shift(pred_yf_cov[:,31:32],  x_c.shape[0]-N+f), label='CONV_32_xf', alpha = 0.5)

# plt.plot(add_shift(pred2_yf[:,0:1], x_l.shape[0]-N), label='lstm_1_xf', alpha = 0.5)
# plt.plot(add_shift(pred2_yf[:,31:32], x_l.shape[0]-N+f), label='lstm_32_xf', alpha = 0.5)

plt.vlines(zn_train_df.shape[0]-N-1-window, 1.05*Y.max(), 0, linestyles='--', label='TrainVal/Test data cut-off', color = 'black')
plt.vlines(zn_train_df.shape[0]-N-1-window +f , 1.05*Y.max(), 0, linestyles='--', label='Last f stop', color = 'green')

plt.xlabel('Время')
plt.ylabel('Значение ')

plt.ylim([0.65*Y.min(), 1.15*Y.max()])

plt.legend()
plt.show()

# %% [markdown]
# #пока не нужно

# %%
# # вычислим батч по данным из "окна" f
# xp = []
# start = zn_train_df.shape[0]-f-window-1
# print(start)
# i = 0
# while start + window + i   < zn_train_df.shape[0]:
#     df_x = zn_train_df.iloc[start + i:start + window+i, 2:zn_train_df.shape[1]].reset_index(drop = 1)# - ntrain_df.iloc[i:window +i, 2:].reset_index(drop = 1)
#     xp.append(df_x.to_numpy())
#     # df_y = zn_train_df.iloc[window+i:window+i+f, zn_train_df.shape[1]-1].reset_index(drop = 1)
#     # y.append(df_y.to_numpy())
#     i += 1
# xp = np.array(xp)
# print(xp.shape)
# xp_c = np.reshape(xp, (-1, xp.shape[1], xp.shape[2], 1))
# xp_l = np.reshape(xp, (-1, xp.shape[1], xp.shape[2]))
# pred_yf_cov =  discriminator.predict(xp_c)* _std + _mean #* (_max - _min) + _min
# pred2_yf = lstm.predict(xp_l)* _std + _mean

# %%
# str(list(pred2[:,31:32].flatten()))

# %%
# str(list(pred2[:,0:1].flatten()))

# %%
# pred_yf_cov[:,31:32].flatten()

# %% [markdown]
# #STOP здесь   STOP здесь        STOP здесь STOP здесь     STOP здесь     STOP здесь

# %%
# dataset_train = keras.preprocessing.timeseries_dataset_from_array(
#     x[:N],
#     y[:N],
#     sequence_length=pastLen,
#     sampling_rate=1,
#     batch_size=batch_size,
# )
# dataset_val = keras.preprocessing.timeseries_dataset_from_array(
#     x[N:],
#     y[N:],
#     sequence_length=pastLen,
#     sampling_rate=1,
#     batch_size=batch_size,
# )

# %%
# discriminator = keras.Sequential(
#     [
#         keras.Input(shape=(x.shape[1], x.shape[2], 1)),
#         layers.Conv2D(24, (9, 9), strides=(1, 1), padding="same", activation='tanh'),
#         #layers.LeakyReLU(alpha=0.5),
#         layers.Conv2D(32, (7, 7), strides=(1, 1), padding="same",  activation='tanh'),
#         #layers.LeakyReLU(alpha=0.5),
#         layers.Conv2D(64, (3, 3), strides=(1, 1), padding="same", activation='tanh'),
#         #layers.LeakyReLU(alpha=0.5),
#         layers.Conv2D(3, (3, 3), strides=(1, 1), padding="same", activation='tanh'),
#         #layers.LeakyReLU(alpha=0.5),
#         layers.GlobalMaxPooling2D(),
#     ],
#     name="discriminator",
# )

# discriminator.summary()

# %%
# def shift(xs, n):
#     e = np.empty_like(xs)
#     if n >= 0:
#         e[:n] = np.nan
#         e[n:] = xs[:-n]
#     else:
#         e[n:] = np.nan
#         e[:n] = xs[-n:]
#     return e

# %%
generator = keras.Sequential(
    [
        keras.Input(shape=(latent_dim,)),
        # строим размер входного вектора 7x7x24 map
        layers.Dense(7 * 7 * latent_dim),
        layers.LeakyReLU(alpha=0.2),
        layers.Reshape((7, 7, latent_dim)),
        layers.Conv2DTranspose(24, (4, 4), strides=(2, 2), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2DTranspose(12, (4, 4), strides=(2, 2), padding="same"),
        layers.LeakyReLU(alpha=0.2),
        layers.Conv2D(1, (7, 7), padding="same", activation="sigmoid"),
        layers.Dense(7),
        
    ],
    name="generator",
)

generator.summary()

# %% [markdown]
# ## Класс со своим этапом обучения `train_step`

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim

    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn

    def train_step(self, batch):

        latent_vectors = self.discriminator(batch)
        generated_images = self.generator(latent_vectors)

        with tf.GradientTape() as tape:
            predictions = self.generator(self.discriminator(batch))
            d_loss = self.loss_fn(batch, predictions)
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights)
        self.d_optimizer.apply_gradients(
            zip(grads, self.discriminator.trainable_weights)
        )

        with tf.GradientTape() as tape:
            predictions = self.generator(latent_vectors)
            g_loss = self.loss_fn(batch, predictions)
        grads = tape.gradient(g_loss, self.generator.trainable_weights)
        self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights))
      
        return {"d_loss": d_loss, "g_loss": g_loss}

    def predict(self,x):
        latent_vectors = self.discriminator(x)
        generated_images = self.generator(latent_vectors)
        return generated_images

# %%
class GANMonitor(keras.callbacks.Callback):
    def __init__(self, num_img=3, latent_dim=latent_dim):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        #latent_vectors = tf.random.normal(shape=(self.num_img, self.latent_dim))
        # print(all_digits[0:3].shape)
        # latent_vectors = self.model.discriminator(tf.convert_to_tensor(all_digits[0:3], dtype=tf.int64))
        #generated_images = self.model.generator(latent_vectors)
        generated_images = self.model.predict(all_digits[0:3])
        generated_images *=255
        generated_images.numpy()
        plt.imshow(np.reshape(generated_images[2], (28, 28)), cmap=pyplot.get_cmap('gray'))
        plt.show()
        for i in range(self.num_img):
            img = keras.preprocessing.image.array_to_img(generated_images[i])
            img.save("generated_img_{i}_{epoch}.png".format(i=i, epoch=epoch))

# %% [markdown]
# ## Учим end-to-end модель

# %%
epochs = 1
steps = 12
gan = GAN(discriminator=discriminator, generator=generator, latent_dim=latent_dim)
gan.compile(
    d_optimizer=keras.optimizers.Adam(learning_rate=0.003),
    g_optimizer=keras.optimizers.Adam(learning_rate=0.003),
    loss_fn=keras.losses.MeanSquaredError(),
)
n = 0
for s in range(steps):
    gan.fit(
      dataset, epochs=epochs, callbacks=[GANMonitor(num_img=3, latent_dim=latent_dim)])
    generated_images = gan.predict(all_digits[n:3+n])
    generated_images *=255
    generated_images.numpy()
    plt.figure(figsize=(5,5))
    k = 0
    w = 0
    for i in range(1,4):
        for j in range(1,3):
          if j == 1:
            plt.subplot(3,2,k+1)
            plt.imshow(x_train[n+w], cmap=pyplot.get_cmap('gray'))
          else:
            plt.subplot(3,2,k+2)
            plt.imshow(np.reshape(generated_images[w], (28, 28)), cmap=pyplot.get_cmap('gray'))
        k +=2
        w+=1

# %%
# epochs = 15

# gan = GAN(discriminator=discriminator, generator=generator, latent_dim=latent_dim)
# gan.compile(
#     d_optimizer=keras.optimizers.Adam(learning_rate=0.003),
#     g_optimizer=keras.optimizers.Adam(learning_rate=0.003),
#     loss_fn=keras.losses.MeanSquaredError(),
# )

# gan.fit(
#     dataset, epochs=epochs, callbacks=[GANMonitor(num_img=3, latent_dim=latent_dim)]
# )

# %%
aaa =all_digits[0:100]

# %%
p = gan.predict(aaa)

# %%
n=0
plt.figure(figsize=(18,18))
k = 0
w = 0
for i in range(1,10):
    for j in range(1,3):
      if j == 1:
        plt.subplot(9,2,k+1)#i*4+j+1)
        plt.imshow(x_train[n+w], cmap=pyplot.get_cmap('gray'))
      else:
        plt.subplot(9,2,k+2)#i*4+j+1)
        plt.imshow(np.reshape(p[n+w], (28, 28))*255, cmap=pyplot.get_cmap('gray'))
       # y_t = np.argmax(y_train10[n+k], axis = 1)
    k +=2
    w+=1
plt.show()

# %%
for i in range(9):  
  pyplot.subplot(330 + 1 + i)
  pyplot.imshow(np.reshape(p[i], (28, 28))*255-x_train[i], cmap=pyplot.get_cmap('gray'))
  #pyplot.imshow(x_train[i], cmap=pyplot.get_cmap('gray'))
  pyplot.show()

# %% [markdown]
# Display the last generated images:

# %%
from IPython.display import Image, display

display(Image("generated_img_0_2.png"))
display(Image("generated_img_1_2.png"))
display(Image("generated_img_2_2.png"))

# %%
display(Image("generated_img_0_0.png"))
display(Image("generated_img_0_1.png"))
display(Image("generated_img_0_2.png"))

# %%
# epochs = 1
# steps = 12
# gan = GAN(discriminator=discriminator, generator=generator, latent_dim=latent_dim)
# gan.compile(
#     d_optimizer=keras.optimizers.Adam(learning_rate=0.003),
#     g_optimizer=keras.optimizers.Adam(learning_rate=0.003),
#     loss_fn=keras.losses.MeanSquaredError(),
# )
# for s in range(steps):
#     gan.fit(
#       dataset, epochs=epochs, callbacks=[GANMonitor(num_img=3, latent_dim=latent_dim)])
#     generated_images = gan.predict(all_digits[0:3])
#     generated_images *=255
#     generated_images.numpy()
#     plt.imshow(np.reshape(generated_images[2], (28, 28)), cmap=pyplot.get_cmap('gray'))
#     plt.show()

# %%
# MNIST 
batch_size = 64
(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
all_digits = np.concatenate([x_train, x_test])
all_digits = all_digits.astype("float32") / 255
all_digits = np.reshape(all_digits, (-1, 28, 28, 1))
dataset = tf.data.Dataset.from_tensor_slices(all_digits)
# генератор батчей
dataset = dataset.shuffle(buffer_size=1024).batch(batch_size).prefetch(32)

# %%
all_digits.shape

# %%
from matplotlib import pyplot
for i in range(9):  
  pyplot.subplot(330 + 1 + i)
  print(x_train[i].shape)
  pyplot.imshow(x_train[i], cmap=pyplot.get_cmap('gray'))
  pyplot.show()
